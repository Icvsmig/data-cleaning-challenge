# %%
import pandas as pd 
import re
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats

# %%
df = pd.read_csv(r'C:\Users\Rahul Miglani\Untitled Folder\WELLCOME_APCspend2013_forThinkful.csv', encoding='latin-1')

# %%
# lets look at the columns and index
df.head()
# these columns are messy with capital letters and whitespaces all over the place so lets fix that first
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# 4                                            £685.88

# %%
# here we want to make sure the column names are consistent and are tidy
# in this case we have PMID/PMCID capitalized, first letter of Publisher , Journal , Article and the COST and Welcome capitalized, we also have spaces in the 
#middle of Journal title and Article title as COST() charged to Welcome(inc VAT when charged)
df.columns
# Out:
# Index(['PMID/PMCID', 'Publisher', 'Journal title', 'Article title',
#        'COST (£) charged to Wellcome (inc VAT when charged)'],
#       dtype='object')

# %%
# Here I am isolating the columns names to strip the whitespace and replace them with '_'and make them all lower case so its consistent and easier to recall
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
# sanity check on columns 
df.head()
# Out:
#               pmid/pmcid publisher           journal_title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        article_title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   cost_(£)_charged_to_wellcome_(inc_vat_when_charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# 4                                            £685.88

# %%
# I don't like the way cost columns is named it is very untidy and messy to call, I will rename it to just Cost
df.rename(columns = {'cost_(£)_charged_to_wellcome_(inc_vat_when_charged)' : 'cost'}, inplace = True )

# %%
# here we want to see the type,null more info about data that I have 
# Cost should be a float instead it is listed as an object 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2127 entries, 0 to 2126
# Data columns (total 5 columns):
# pmid/pmcid       1928 non-null object
# publisher        2127 non-null object
# journal_title    2126 non-null object
# article_title    2127 non-null object
# cost             2127 non-null object
# dtypes: object(5)
# memory usage: 83.2+ KB

# %%
# Replace the pound symbol with nothing 
df.cost = df.cost.str.replace('£','')

# %%
# convert it to a float to be able to evaluate the mean, median, and std of the cost 
df.cost = df.cost.str.replace('$','').astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2127 entries, 0 to 2126
# Data columns (total 5 columns):
# pmid/pmcid       1928 non-null object
# publisher        2127 non-null object
# journal_title    2126 non-null object
# article_title    2127 non-null object
# cost             2127 non-null float64
# dtypes: float64(1), object(4)
# memory usage: 83.2+ KB

# %%
df.journal_title = df['journal_title'].str.lower()

# %%
df.journal_title = df['journal_title'].str.replace(' ','')

# %%
df['journal_title'].value_counts()
# Out:
# plosone                                                     200
# journalofbiologicalchemistry                                 53
# neuroimage                                                   29
# nucleicacidsresearch                                         25
# plosgenetics                                                 24
# plospathogens                                                24
# proceedingsofthenationalacademyofsciences                    22
# plosneglectedtropicaldiseases                                20
# naturecommunications                                         19
# humanmoleculargenetics                                       19
# bmcpublichealth                                              15
# brain                                                        14
# journalofneuroscience                                        13
# movementdisorders                                            13
# developmentalcell                                            12
# biochemicaljournal                                           12
# journalofgeneralvirology                                     11
# currentbiology                                               11
# malariajournal                                               10
# ploscomputationalbiology                                     10
# bmj                                                          10
# development                                                   9
# bmjopen                                                       9
# cellreports                                                   9
# neuron                                                        9
# journalofphysiology                                           8
# molecularmicrobiology                                         8
# hepatology                                                    8
# journalofstructuralbiology                                    8
# journalofvirology                                             8
#                                                            ...
# infectiongeneticsandevolution                                 1
# clinicalradiology                                             1
# frontiersincognition                                          1
# theranostics                                                  1
# experimentalcellresearch                                      1
# birthdefectsresearchparta:clinicalandmolecularteratology      1
# bmjqualityandsafety                                           1
# journalofacquiredimmunedeficiencysyndroms(jaids)              1
# cellpress-cellreports                                         1
# arthritisresearchandtherapy                                   1
# annalsofhumangenetics                                         1
# europeanjournalofcellbiology                                  1
# bmcmedicalimaging                                             1
# circulationresearch                                           1
# journaloftheroyalsociety,interface                            1
# pyschologicalmedicine                                         1
# humanresourcesforhealth                                       1
# journalofabnormalpsychology                                   1
# aidsbehav                                                     1
# plantbiotechnologyjournal                                     1
# proteinexprpurif.                                             1
# frontiersinendocrinology                                      1
# neuromusculardisorders                                        1
# eurjimmunol                                                   1
# journalofarchaeologicalscience                                1
# endocrinerelatedcancer                                        1
# implementsci.                                                 1
# journaloforthopedicresearch                                   1
# journalofbiomedicalgraphicsandcomputing                       1
# jsteroidbiochemmolbiol                                        1
# Name: journal_title, Length: 895, dtype: int64

# %%
#Here is the count of the top 5 journals 
(df.journal_title).value_counts().nlargest(5)
# Out:
# plosone                         200
# journalofbiologicalchemistry     53
# neuroimage                       29
# nucleicacidsresearch             25
# plosgenetics                     24
# Name: journal_title, dtype: int64

# %%
df1 = df.groupby('journal_title').count()
top5 = df1.nlargest(5,'article_title')

# %%
df['cost'] = np.array(df['cost'])
df['cost'] = scipy.stats.mstats.winsorize(df['cost'], limits=[0.05, 0.05])

# %%
#create a groupby function that is grouped by journal and we want to look at the cost column 
group_data = df['cost'].groupby(df['journal_title'])
group_data

# %%
# look that length of the list I created to save my columns 
len(list(df['cost'].groupby(df['journal_title'])))
# Out:
# 895

# %%
list(df['cost'].groupby(df['journal_title']))
# Out:
# [('academyofnutritionanddietetics', 439    2379.54
#   Name: cost, dtype: float64), ('acschemicalbiology', 8     1294.59
#   9     1294.78
#   19    1267.76
#   20    2286.73
#   21     947.07
#   Name: cost, dtype: float64), ('acschemicalneuroscience', 22    1186.8
#   Name: cost, dtype: float64), ('acsnano', 23    734.0
#   34    734.0
#   Name: cost, dtype: float64), ('actacrystallographica,sectiond', 921    757.18
#   Name: cost, dtype: float64), ('actacrystallographicasectiond,biologicalcrystallography',
#   927    771.42
#   Name: cost, dtype: float64), ('actacrystallographicasectiond:biologicalcrystallography',
#   920    773.74
#   Name: cost, dtype: float64), ('actacrystallographicasectionf:structuralbiologyandcrystallizationcommunications',
#   928    785.60
#   929    807.67
#   Name: cost, dtype: float64), ('actacrystallographyd', 922    774.19
#   Name: cost, dtype: float64), ('actad', 923    750.16
#   Name: cost, dtype: float64), ('actadermatovenereologica', 1711    734.0
#   Name: cost, dtype: float64), ('actadiabetologica', 1716    2336.28
#   Name: cost, dtype: float64), ('actaf', 924    754.9
#   Name: cost, dtype: float64), ('actaneuropathol', 1717    1901.04
#   Name: cost, dtype: float64), ('actaneuropathologica', 1718    1884.01
#   1719    2250.97
#   1720    2348.21
#   Name: cost, dtype: float64), ('actaopthalmologica', 2051    2270.16
#   Name: cost, dtype: float64), ('actaphysiol', 1871    1991.5
#   Name: cost, dtype: float64), ('addiction', 1872    1919.51
#   1873    2352.94
#   Name: cost, dtype: float64), ('advancesinexperimentalmedicineandbiology',
#   1721    1928.45
#   1722    1928.46
#   1723    1928.46
#   1724    1928.46
#   Name: cost, dtype: float64), ('age', 1803    2338.28
#   1808    2002.00
#   Name: cost, dtype: float64), ('ageandageing', 1186    2040.0
#   Name: cost, dtype: float64), ('ageing&society', 353    1695.0
#   Name: cost, dtype: float64), ('agingcell', 1874    1970.57
#   Name: cost, dtype: float64), ('aids', 2115    1968.63
#   2123    1834.77
#   2125    2374.52
#   Name: cost, dtype: float64), ('aidsbehav', 1797    1834.77
#   Name: cost, dtype: float64), ('aidscare', 1811    2145.60
#   1812    2399.28
#   1813    2399.28
#   1824    2232.74
#   Name: cost, dtype: float64), ('aidsjournal', 2116    2015.72
#   Name: cost, dtype: float64), ('aidsresearchandtherapy', 235    1240.0
#   Name: cost, dtype: float64), ('aidsuk', 2117    1836.92
#   2118    1836.92
#   Name: cost, dtype: float64), ('alcoholandalcoholism', 1109    2040.0
#   Name: cost, dtype: float64), ('alimentrarypharmacology&therapeutics',
#   1875    2373.59
#   1876    2373.59
#   Name: cost, dtype: float64), ('americaljournalofpsychiatry', 44    2350.02
#   Name: cost, dtype: float64), ('americanchemicalsociety', 24    1533.29
#   Name: cost, dtype: float64), ('americanethnologist', 1877    1870.32
#   2007    1870.67
#   Name: cost, dtype: float64), ('americanjnlepidemiology', 1110    2040.0
#   Name: cost, dtype: float64), ('americanjournalforclinicalnutrition',
#   416    1891.19
#   Name: cost, dtype: float64), ('americanjournalofbioethics--neuroscience',
#   1825    2465.77
#   Name: cost, dtype: float64), ('americanjournalofclinicalnutrition',
#   417    1953.76
#   Name: cost, dtype: float64), ('americanjournalofepidemiology', 1111    2040.0
#   1112    2040.0
#   1187    1700.0
#   Name: cost, dtype: float64), ('americanjournalofgeriatricpsychiatry',
#   440    2404.53
#   Name: cost, dtype: float64), ('americanjournalofhumangenetics',
#   374    2418.34
#   441    2296.94
#   442    2334.41
#   443    2434.04
#   444    3780.00
#   Name: cost, dtype: float64), ('americanjournalofmedicalgenetics',
#   934    2307.01
#   Name: cost, dtype: float64), ('americanjournalofmedicalgeneticsparta',
#   1878    1500.0
#   Name: cost, dtype: float64), ('americanjournalofpathology', 81    995.31
#   Name: cost, dtype: float64), ('americanjournalofpreventivemedicine',
#   445    2377.65
#   446    2377.65
#   830    1834.77
#   Name: cost, dtype: float64), ('americanjournalofpsychiatry', 43    2351.73
#   Name: cost, dtype: float64), ('americanjournalofpublichealth', 59    1422.25
#   Name: cost, dtype: float64), ('americanjournaloftransplantation',
#   2052    1884.30
#   2053    2373.84
#   2107    1900.70
#   Name: cost, dtype: float64), ('americanjournaloftropicalmedicine&hygiene',
#   1679    1646.36
#   1680    1646.36
#   1681    1651.30
#   Name: cost, dtype: float64), ('americansocietyfornutrition', 100    734.0
#   Name: cost, dtype: float64), ('amjbioeth', 1822    1804.19
#   Name: cost, dtype: float64), ('amjtropmedhyg', 1868    1152.5
#   Name: cost, dtype: float64), ('analbioanalchem.', 1725    1902.97
#   Name: cost, dtype: float64), ('analyticalbiochemistry', 447    2381.62
#   Name: cost, dtype: float64), ('analyticalchemistry', 25    2082.74
#   26    2314.10
#   27     759.67
#   Name: cost, dtype: float64), ('angewandechemie', 1879    2979.91
#   Name: cost, dtype: float64), ('angewandtechemie', 1880    2250.0
#   Name: cost, dtype: float64), ('angewandtechemieinternationaledition',
#   2054    2437.19
#   2055    2437.19
#   2056    2437.19
#   Name: cost, dtype: float64), ('angewchemsinted', 2108    3026.17
#   Name: cost, dtype: float64), ('animalbehaviour', 448    1806.38
#   449    1816.38
#   Name: cost, dtype: float64), ('annalsofhumangenetics', 1881    2234.61
#   Name: cost, dtype: float64), ('annalsofneurology', 1882    1500.00
#   1883    2184.22
#   1884    2010.24
#   1885    2010.24
#   2057    2276.48
#   Name: cost, dtype: float64), ('annalsofscience', 1814    2337.6
#   Name: cost, dtype: float64), ('annalsofthenewyorkacademyofsciences',
#   1886    1500.00
#   1887    2293.27
#   Name: cost, dtype: float64), ('antimicobialagentsandchemotherapy',
#   342    1831.18
#   Name: cost, dtype: float64), ('antimicrobialagentsandchemotherapy',
#   82     1287.19
#   83     1287.20
#   84     1521.66
#   167    1299.39
#   Name: cost, dtype: float64), ('antimicrobialagfentsandchemotherapy',
#   85    3750.05
#   Name: cost, dtype: float64), ('antioxidants&redoxsignaling', 987    1347.79
#   Name: cost, dtype: float64), ('antioxidantsandredoxsignaling', 988    1681.94
#   990    2528.64
#   Name: cost, dtype: float64), ('appliedenergy', 450    2377.65
#   Name: cost, dtype: float64), ('archivesofdiseaseinchildhood', 303    2040.0
#   304    2340.0
#   319    2040.0
#   Name: cost, dtype: float64), ('arthritis&rheumatism', 1888    1000.00
#   1889    1500.00
#   1890    1969.02
#   Name: cost, dtype: float64), ('arthritisandrheumatism', 1891    1500.0
#   1892    1500.0
#   Name: cost, dtype: float64), ('arthritisresearch&therapy', 175    1608.0
#   Name: cost, dtype: float64), ('arthritisresearchandtherapy', 252    1315.8
#   Name: cost, dtype: float64), ('asianjournalofpsychiatry', 451    2014.59
#   452    2423.27
#   Name: cost, dtype: float64), ('asnneuro', 1317    1453.42
#   Name: cost, dtype: float64), ('atherosclerosis', 453    2317.94
#   454    2404.27
#   Name: cost, dtype: float64), ('autophagy', 969    734.0
#   Name: cost, dtype: float64), ('azania:archaeologicalresearchinafrica',
#   1810    1823.76
#   Name: cost, dtype: float64), ('bba-molecularbasisofdisease', 455    2366.57
#   Name: cost, dtype: float64), ('behavioralneuroscience', 45    3021.72
#   46    3209.63
#   47    3211.77
#   Name: cost, dtype: float64), ('behaviorresearchandtherapy', 456    2212.09
#   457    2335.37
#   Name: cost, dtype: float64), ('behaviouralbrainresearch', 460    2298.35
#   Name: cost, dtype: float64), ('behaviourresearchandtherapy', 458    2269.53
#   459    2269.53
#   Name: cost, dtype: float64), ('biinformatics', 1188    1047.0
#   Name: cost, dtype: float64), ('biochemicalandbiophysicalresearchcommunications',
#   461    1475.4
#   462    2246.4
#   Name: cost, dtype: float64), ('biochemicaljournal', 1318    1800.0
#   1319    1800.0
#   1320    1800.0
#   1321    2050.0
#   1329    1800.0
#   1330    1800.0
#   1331    1800.0
#   1332    1800.0
#   1333    2100.0
#   1334    2100.0
#   1335    2100.0
#   1336    2100.0
#   Name: cost, dtype: float64), ('biochemicaljournals', 1322    1800.0
#   Name: cost, dtype: float64), ('biochemicalpharmacology', 463    2961.92
#   Name: cost, dtype: float64), ('biochemicalsocietytransactions',
#   1323    2100.0
#   1324     900.0
#   1337    1800.0
#   Name: cost, dtype: float64), ('biochemistry', 13    734.0
#   Name: cost, dtype: float64), ('biochemjournal', 173    1800.0
#   Name: cost, dtype: float64), ('biochemsoctrans', 1328    1800.0
#   Name: cost, dtype: float64), ('biochimicaetbioohysicaacta-generegulatorymechanisms',
#   464    2476.42
#   Name: cost, dtype: float64), ('biochimicaetbioohysicaacta-molecularbasisofdisease',
#   465    2307.23
#   Name: cost, dtype: float64), ('biochimicaetbiophysicaacta(bba)-molecularcellresearch',
#   467    2415.37
#   Name: cost, dtype: float64), ('biochimicaetbiophysicaacta-molecularbasisofdisease',
#   466    2370.96
#   Name: cost, dtype: float64), ('biochimie', 468    2315.48
#   Name: cost, dtype: float64), ('bioconjugatechemistry', 28    1565.26
#   Name: cost, dtype: float64), ('bioethics', 1893    1901.02
#   1894    1969.41
#   1895    1969.41
#   2008    1898.01
#   Name: cost, dtype: float64), ('biogerontology', 1726    2282.59
#   Name: cost, dtype: float64), ('bioinformatics', 1189    1700.0
#   1190    1700.0
#   1191    2040.0
#   1192    2100.0
#   Name: cost, dtype: float64), ('bioinformaticsonline', 1182     850.0
#   1193    1700.0
#   1194     850.0
#   Name: cost, dtype: float64), ('biologicalchemistry', 115    946.55
#   Name: cost, dtype: float64), ('biologicalpsychiatry', 469    2142.93
#   470    2330.13
#   471    2429.17
#   472    2469.95
#   Name: cost, dtype: float64), ('biologicalpsychology', 473    2435.38
#   Name: cost, dtype: float64), ('biologicialchemistry', 116    1281.59
#   Name: cost, dtype: float64), ('biology', 1341    1836.91
#   Name: cost, dtype: float64), ('biologyletters', 1628    1260.0
#   1629    1680.0
#   1630    1680.0
#   1631    2040.0
#   Name: cost, dtype: float64), ('biologyopen', 387     1044.0
#   388     1044.0
#   389     1044.0
#   1838    1044.0
#   1841    1044.0
#   Name: cost, dtype: float64), ('biolopen', 1840    1014.74
#   Name: cost, dtype: float64), ('biomacromolecules', 1    2381.04
#   Name: cost, dtype: float64), ('biomaterials', 474    2329.03
#   475    2466.39
#   Name: cost, dtype: float64), ('biomedcentral', 176    1350.0
#   Name: cost, dtype: float64), ('biomedicalmicrodevices', 1727    2236.16
#   Name: cost, dtype: float64), ('biomolecularnmrassignments', 1804    1930.88
#   1809    1916.11
#   Name: cost, dtype: float64), ('biophysicaljournal', 244    734.0
#   245    734.0
#   337    734.0
#   Name: cost, dtype: float64), ('biopolymers', 948     1981.72
#   1896    1981.77
#   Name: cost, dtype: float64), ('biosciencereports', 1338    834.0
#   Name: cost, dtype: float64), ('biosocieties', 1026    1800.0
#   1276    1920.0
#   Name: cost, dtype: float64), ('biosystems', 476    2863.73
#   Name: cost, dtype: float64), ('birthdefectsresearchparta:clinicalandmolecularteratology',
#   1897    1500.0
#   Name: cost, dtype: float64), ('birthdefectsresearchparta:clinicalandmolecularteratology\xa0',
#   1898    1500.0
#   Name: cost, dtype: float64), ('bjophthalmol', 278    2340.0
#   Name: cost, dtype: float64), ('bjp', 1856    3000.0
#   Name: cost, dtype: float64), ('blood', 101    1260.26
#   102    1260.26
#   104    1230.40
#   105    1288.14
#   106    1340.75
#   107    1527.20
#   108    1543.44
#   Name: cost, dtype: float64), ('bloodjournal2012', 103    1597.98
#   109    1578.43
#   Name: cost, dtype: float64), ('bmcbiology', 178    1674.0
#   Name: cost, dtype: float64), ('bmcgenetics', 179    1375.8
#   Name: cost, dtype: float64), ('bmcgenomebiology', 180    2010.0
#   Name: cost, dtype: float64), ('bmcgenomics', 181    1204.38
#   182    1254.60
#   183    1476.00
#   226     734.00
#   Name: cost, dtype: float64), ('bmcgenomics.', 227    3780.0
#   Name: cost, dtype: float64), ('bmchealthservicesresearch', 184    1536.0
#   253    1128.0
#   Name: cost, dtype: float64), ('bmcinfectiousdiseases', 228    1280.0
#   242    1536.0
#   254    1375.8
#   Name: cost, dtype: float64), ('bmcmedicalethics', 255    1315.8
#   Name: cost, dtype: float64), ('bmcmedicalgenetics', 185    1536.0
#   Name: cost, dtype: float64), ('bmcmedicalimaging', 256    1290.0
#   Name: cost, dtype: float64), ('bmcmedicine', 186    1734.0
#   187    1794.0
#   257    1605.3
#   Name: cost, dtype: float64), ('bmcmicrobiology', 188    1375.8
#   Name: cost, dtype: float64), ('bmcmolecularbiology', 189    1536.0
#   Name: cost, dtype: float64), ('bmcneurology', 190    1476.0
#   Name: cost, dtype: float64), ('bmcneuroscience', 191    1314.6
#   Name: cost, dtype: float64), ('bmcpediatrics', 236    1280.0
#   Name: cost, dtype: float64), ('bmcpsychiatry', 192    1180.80
#   193    1650.51
#   Name: cost, dtype: float64), ('bmcpublichealth', 177    1536.0
#   194    1314.6
#   195    1536.0
#   196     734.0
#   237    1280.0
#   238    1280.0
#   239    1280.0
#   258    1254.6
#   259    1315.8
#   260    1315.8
#   261    1315.8
#   262    1536.0
#   263    1536.0
#   264    1608.0
#   265     734.0
#   Name: cost, dtype: float64), ('bmcresearchnotes', 197    734.0
#   Name: cost, dtype: float64), ('bmcveterinaryresearch', 198    1230.0
#   Name: cost, dtype: float64), ('bmj', 279    3000.0
#   280    3600.0
#   281     810.0
#   301    1500.0
#   305    3600.0
#   320    3000.0
#   329    3000.0
#   330    3000.0
#   331    3000.0
#   332    3000.0
#   Name: cost, dtype: float64), ('bmjopen', 282    1500.0
#   283    1620.0
#   284    1652.4
#   285    1652.4
#   306    1500.0
#   307    1620.0
#   321    1620.0
#   322    1680.0
#   335    1275.0
#   Name: cost, dtype: float64), ('bmjqualityandsafety', 308    1950.0
#   Name: cost, dtype: float64), ('bmsgenomics', 199    1608.0
#   Name: cost, dtype: float64), ('bone', 477    2295.39
#   478    2328.43
#   479    2451.81
#   Name: cost, dtype: float64), ('brain', 1113    2040.0
#   1114    2040.0
#   1115    2040.0
#   1116    2040.0
#   1117    2400.0
#   1118    2400.0
#   1119    2400.0
#   1120    2400.0
#   1121    2400.0
#   1165    2040.0
#   1195    2000.0
#   1196    2040.0
#   1197    2040.0
#   1198    2040.0
#   Name: cost, dtype: float64), ('brainandcognition', 480    2345.19
#   481    2457.25
#   Name: cost, dtype: float64), ('brainandlanguage', 482    1456.18
#   483    2498.61
#   Name: cost, dtype: float64), ('brainonline', 1199    1700.0
#   1200    1700.0
#   1201    2040.0
#   1202    2040.0
#   Name: cost, dtype: float64), ('brainresearch', 484    2272.21
#   485    2539.89
#   Name: cost, dtype: float64), ('brainstructureandfunction', 1728    1639.06
#   Name: cost, dtype: float64), ('braintopography', 1729    1889.9
#   Name: cost, dtype: float64), ('briefingsinbioinformatics', 1122    2100.0
#   Name: cost, dtype: float64), ('briefingsinfunctionalgenomics', 1203    2040.0
#   1204    2100.0
#   Name: cost, dtype: float64), ('britishjounalofpharmacology', 2058    2268.41
#   Name: cost, dtype: float64), ('britishjournalforthehistoryofscience',
#   354    1695.0
#   Name: cost, dtype: float64), ('britishjournalofcancer', 1027    2040.0
#   1028    2040.0
#   Name: cost, dtype: float64), ('britishjournalofclinicalpharmacology',
#   1899    2184.22
#   2059    2307.69
#   Name: cost, dtype: float64), ('britishjournalofdermatology', 1900    1954.74
#   2024    1896.64
#   Name: cost, dtype: float64), ('britishjournalofhaematology', 1901    1929.35
#   Name: cost, dtype: float64), ('britishjournalofophthalmology', 286    2040.0
#   Name: cost, dtype: float64), ('britishjournalofopthalmology', 287    2340.0
#   Name: cost, dtype: float64), ('britishjournalofpharmacology', 1902    1868.00
#   1903    1900.90
#   1904    1952.24
#   2060    2345.58
#   2061    2373.57
#   Name: cost, dtype: float64), ('britishjournalofpsychiatry', 1624    3000.0
#   1857    3000.0
#   Name: cost, dtype: float64), ('britishjournalofthehistoryofscience',
#   355    850.0
#   Name: cost, dtype: float64), ('britishmedicalbulletin', 1123    2100.0
#   Name: cost, dtype: float64), ('britishmedicaljournal', 288     3000.0
#   1205    2040.0
#   Name: cost, dtype: float64), ('britshjournalofpsychiatry', 1625    3000.0
#   Name: cost, dtype: float64), ('brtjnlclinicalpharmacology', 2009    2009.65
#   Name: cost, dtype: float64), ('bulletinofthehistoryofmedicine',
#   959    1880.66
#   Name: cost, dtype: float64), ('calcifiedtissueinternational', 1730    2002.76
#   Name: cost, dtype: float64), ('canadianjournalofafricanstudies',
#   1815    2145.6
#   Name: cost, dtype: float64), ('cancerletters', 486    2515.57
#   Name: cost, dtype: float64), ('cancerresearch', 1865    799.44
#   Name: cost, dtype: float64), ('cardiovascularresearch', 1166    2040.0
#   1268    2040.0
#   1272    1020.0
#   Name: cost, dtype: float64), ('cell', 487    1366.08
#   488    3208.69
#   489    3780.00
#   490    3780.00
#   491    3780.00
#   Name: cost, dtype: float64), ('celladhesionandmigration', 970    734.0
#   Name: cost, dtype: float64), ('cellandtissueresearch', 1731    1908.38
#   Name: cost, dtype: float64), ('cellcalcium', 492    2363.14
#   Name: cost, dtype: float64), ('cellcycle', 971    734.00
#   972    734.00
#   973    783.73
#   974    812.96
#   983    762.88
#   984    804.61
#   Name: cost, dtype: float64), ('celldeath&disease', 1029    2040.0
#   1030    2040.0
#   1031    2520.0
#   Name: cost, dtype: float64), ('celldeathanddifferentiation', 1032    3000.0
#   Name: cost, dtype: float64), ('celldeathanddisease', 1033    2400.0
#   1050    2400.0
#   Name: cost, dtype: float64), ('celldeathdifferentiation', 1056    3000.0
#   Name: cost, dtype: float64), ('cellhost&microbe', 844    3780.0
#   Name: cost, dtype: float64), ('cellhostandmicrobe', 493    3780.0
#   Name: cost, dtype: float64), ('celljournal', 494    3780.0
#   Name: cost, dtype: float64), ('cellmetabolism', 495    3780.0
#   496    3780.0
#   831    3780.0
#   Name: cost, dtype: float64), ('cellpress-cellreports', 418    3780.0
#   Name: cost, dtype: float64), ('cellreports', 415    3154.01
#   419    3242.21
#   420    3780.00
#   421    3780.00
#   422    3780.00
#   423    3780.00
#   434    3712.80
#   497    3100.01
#   498    3780.00
#   Name: cost, dtype: float64), ('cellstemcell', 499    3352.04
#   500    3716.09
#   Name: cost, dtype: float64), ('cellularandmolecularcellsciences',
#   1732    1918.46
#   Name: cost, dtype: float64), ('cellularandmolecularlifesciences',
#   1733    1629.33
#   1734    1882.23
#   1735    1897.85
#   1736    1951.80
#   1737    2226.74
#   Name: cost, dtype: float64), ('cellularmicrobiology', 251     1800.00
#   935     2400.85
#   938     2270.50
#   939     2284.62
#   1905    1500.00
#   Name: cost, dtype: float64), ('cellularsignalling', 501    2267.26
#   502    2400.93
#   Name: cost, dtype: float64), ('centaurus', 2062    2292.03
#   Name: cost, dtype: float64), ('cerebralcortex', 1124    1875.0
#   1125    2250.0
#   1126    2250.0
#   1127    2550.0
#   1206    1700.0
#   1207    2040.0
#   1208    3780.0
#   Name: cost, dtype: float64), ('cerebralcortexonline', 1209    2040.0
#   1210    2040.0
#   1211    2040.0
#   Name: cost, dtype: float64), ('cerebralcortexprint', 1183    3177.6
#   Name: cost, dtype: float64), ('channels', 975    734.0
#   Name: cost, dtype: float64), ('chembiochem', 1906    1500.00
#   1907    2083.48
#   1908    2153.41
#   2063    2048.93
#   2109    1851.15
#   Name: cost, dtype: float64), ('chemicalcommunication', 1650    1000.0
#   Name: cost, dtype: float64), ('chemicalsocietyreviews', 1651    1740.0
#   Name: cost, dtype: float64), ('chemistry-europeanjournal', 1909    2051.27
#   Name: cost, dtype: float64), ('chemmedchem', 2110    1812.89
#   2111    1816.70
#   2112    2168.05
#   Name: cost, dtype: float64), ('chemsitry&biology', 503    2184.22
#   Name: cost, dtype: float64), ('chest', 35    2383.94
#   Name: cost, dtype: float64), ('child:care,healthdevelopment', 2010    2260.32
#   Name: cost, dtype: float64), ('child:care,heath&development', 2033    1834.77
#   Name: cost, dtype: float64), ('childneuropsychology', 1816    2145.6
#   Name: cost, dtype: float64), ('childpsychologypsychiatry', 1910    2302.93
#   Name: cost, dtype: float64), ('childsnervsyst', 1802    1831.38
#   Name: cost, dtype: float64), ('chromosomeresearch', 1738    2258.39
#   Name: cost, dtype: float64), ('chronicillness', 1655    1920.0
#   1656    1920.0
#   1657    1920.0
#   Name: cost, dtype: float64), ('circulationresearch', 2122    1334.15
#   Name: cost, dtype: float64), ('clinicalandexperimentalallergy',
#   946    2329.11
#   Name: cost, dtype: float64), ('clinicalandvaccineimmunology', 86    743.85
#   Name: cost, dtype: float64), ('clinicalgenetics', 1911    2864.53
#   Name: cost, dtype: float64), ('clinicalinfectiousdiseases', 1128    1700.0
#   1129    2625.6
#   1167    1700.0
#   1212    2625.6
#   1265    1700.0
#   Name: cost, dtype: float64), ('clinicalinfectiousdiseasesonline',
#   1130    2040.0
#   Name: cost, dtype: float64), ('clinicalneurologyandneurosurgery',
#   504    2455.82
#   Name: cost, dtype: float64), ('clinicalproteomics', 200    1242.0
#   Name: cost, dtype: float64), ('clinicalradiology', 505    2262.3
#   Name: cost, dtype: float64), ('clinicaltranscriptionalscience',
#   2046    2314.69
#   Name: cost, dtype: float64), ('cliniclainfectiousdisease', 1168    2040.0
#   Name: cost, dtype: float64), ('cognition', 506    1473.92
#   Name: cost, dtype: float64), ('cognitivedevelopment', 507    1439.45
#   Name: cost, dtype: float64), ('cognitiveprocessing', 1739    1903.03
#   Name: cost, dtype: float64), ('cognitivetherapyandresearch', 1740    1989.65
#   Name: cost, dtype: float64), ('computationalbiology', 1342    1679.71
#   Name: cost, dtype: float64), ('consciousness&cognition', 508    2386.47
#   Name: cost, dtype: float64), ('consciousnessandcognition', 509    1319.74
#   510    2330.13
#   Name: cost, dtype: float64), ('cortex', 511     1758.99
#   512     2058.64
#   513     2345.19
#   514     2351.06
#   515     2420.79
#   1621    2380.79
#   Name: cost, dtype: float64), ('costeffectivenessandresourceallocation',
#   266    1302.0
#   Name: cost, dtype: float64), ('criminalbehaviorandmentalhealth',
#   2064    2377.65
#   Name: cost, dtype: float64), ('currbiol.', 841    3780.0
#   Name: cost, dtype: float64), ('currentanalyticalchemistry', 170    2142.99
#   Name: cost, dtype: float64), ('currentatherosclerosisreports',
#   1741    2147.11
#   1742    2311.54
#   Name: cost, dtype: float64), ('currentbiology', 516    3213.28
#   517    3635.15
#   518    3780.00
#   519    3780.00
#   520    3780.00
#   521    3780.00
#   522    3780.00
#   523    3780.00
#   524     734.00
#   525    3780.00
#   526    3780.00
#   Name: cost, dtype: float64), ('currentobstetricsandgynecologyreports',
#   1743    2321.55
#   Name: cost, dtype: float64), ('currentopinioninneurobiology', 527    2378.95
#   Name: cost, dtype: float64), ('currentopinionmicrobiology', 528    2979.0
#   Name: cost, dtype: float64), ('currentopinionsinneurobiology', 529    2429.17
#   Name: cost, dtype: float64), ('currenttopicsinmedicinalchemistry',
#   169    2291.22
#   Name: cost, dtype: float64), ('cytoskeleton', 1912    1977.72
#   Name: cost, dtype: float64), ('daltontransactions', 1652    1632.0
#   Name: cost, dtype: float64), ('database', 1213    960.0
#   Name: cost, dtype: float64), ('depressionandanxiety', 2065    2368.42
#   Name: cost, dtype: float64), ('dermatologicsurgery', 2066    2257.56
#   Name: cost, dtype: float64), ('dev.worldbioeth', 2037    1834.77
#   2038    1834.77
#   Name: cost, dtype: float64), ('developingworldbioethics', 1869    1653.02
#   1913    1954.14
#   2011    1982.68
#   Name: cost, dtype: float64), ('development', 390     1044.0
#   391     1620.0
#   392     1620.0
#   393     2400.0
#   394     2400.0
#   395     2400.0
#   396     2400.0
#   1842    1620.0
#   1844    1620.0
#   Name: cost, dtype: float64), ('developmentalbiology', 531    1981.38
#   Name: cost, dtype: float64), ('developmentalcell', 397    1044.00
#   532    2987.00
#   533    3575.88
#   534    3780.00
#   535    3780.00
#   536    3780.00
#   537    3780.00
#   538    3780.00
#   539     734.00
#   540    3780.00
#   541    3780.00
#   542    3780.00
#   Name: cost, dtype: float64), ('developmentalcognitiveneuroscience',
#   543    1764.06
#   544    2457.25
#   Name: cost, dtype: float64), ('developmentalscience', 1915    1500.0
#   Name: cost, dtype: float64), ('developmentcell', 530    3630.64
#   Name: cost, dtype: float64), ('developmentdynamics', 1914    2400.0
#   Name: cost, dtype: float64), ('developmentgenesandevolution', 1744    2230.1
#   Name: cost, dtype: float64), ('developmentscience', 949    2351.81
#   Name: cost, dtype: float64), ('devworldbioeth.', 2034    1834.77
#   2035    1834.77
#   2036    1834.77
#   Name: cost, dtype: float64), ('diabeticmedicine', 1916    2304.31
#   1917    2310.95
#   1918    2384.10
#   2067    2377.66
#   Name: cost, dtype: float64), ('diabetologia', 1745    2211.52
#   1746    2289.06
#   1747    2315.78
#   Name: cost, dtype: float64), ('diagnosticmicrobiologyandinfectiousdisease',
#   545    2252.53
#   Name: cost, dtype: float64), ('diseasemodelsandmechanisms', 398     1620.0
#   1839    2400.0
#   Name: cost, dtype: float64), ('drugandalcoholreview', 2012    1966.31
#   Name: cost, dtype: float64), ('ecologyandevolution', 1919    1440.0
#   Name: cost, dtype: float64), ('ecologyletters', 1920    2388.08
#   Name: cost, dtype: float64), ('economichistoryreview', 2068    1901.02
#   Name: cost, dtype: float64), ('elsevier', 546    2152.76
#   547    2174.85
#   548    2198.03
#   549    2269.15
#   550    2312.30
#   551    2470.86
#   552    3780.00
#   Name: cost, dtype: float64), ('embo', 1057    3120.0
#   Name: cost, dtype: float64), ('embojournal', 1058    3120.0
#   1059    3120.0
#   1060    3120.0
#   1061    3120.0
#   1062    3120.0
#   1063    3120.0
#   1106    3120.0
#   Name: cost, dtype: float64), ('embomolecularmedicine', 947     2252.44
#   958     2868.08
#   1921    3078.92
#   Name: cost, dtype: float64), ('emboreports', 1051    3120.0
#   1064    3120.0
#   1065    3780.0
#   Name: cost, dtype: float64), ('emotion', 48    2534.53
#   Name: cost, dtype: float64), ('endeavour', 553    2419.71
#   554     734.00
#   Name: cost, dtype: float64), ('endocrinerelatedcancer', 1682    1150.0
#   Name: cost, dtype: float64), ('endocrinology', 845     2350.99
#   846     2352.94
#   1845    1875.00
#   1846    1864.86
#   1847    2246.22
#   1848    2247.02
#   Name: cost, dtype: float64), ('englishstudies', 1817    2475.6
#   Name: cost, dtype: float64), ('environmentandplanninga', 1277    1800.0
#   Name: cost, dtype: float64), ('epidemiologyandinfection', 356    1800.0
#   357    2034.0
#   Name: cost, dtype: float64), ('epigenetics', 976    734.0
#   977    734.0
#   Name: cost, dtype: float64), ('epigentics', 978    734.0
#   979    734.0
#   Name: cost, dtype: float64), ('epilepsia', 1922    1500.00
#   2039    1834.77
#   2040    1834.77
#   Name: cost, dtype: float64), ('epilepsyresearch', 555    2483.12
#   Name: cost, dtype: float64), ('essaysinbiochemistry', 1325    734.0
#   Name: cost, dtype: float64), ('ethnhealth', 1823    1987.56
#   Name: cost, dtype: float64), ('eukaryoticcell', 87    1653.18
#   88    2316.16
#   Name: cost, dtype: float64), ('eurjimmunol', 2041    1834.77
#   Name: cost, dtype: float64), ('europeanchildandadolescentpsychiatry',
#   1748    2331.95
#   Name: cost, dtype: float64), ('europeanchildandadolescentpsychiatty',
#   1749    2285.92
#   Name: cost, dtype: float64), ('europeanheartjournalonline', 1131    2040.0
#   Name: cost, dtype: float64), ('europeanhistoryquarterly', 1674    800.0
#   Name: cost, dtype: float64), ('europeanjournalofcellbiology', 556    2228.0
#   Name: cost, dtype: float64), ('europeanjournalofclinicalpharmacology',
#   1750    1632.89
#   Name: cost, dtype: float64), ('europeanjournalofendocrinology', 246    1200.0
#   852    1440.0
#   Name: cost, dtype: float64), ('europeanjournalofenglishstudies',
#   1818    2260.8
#   Name: cost, dtype: float64), ('europeanjournalofepidemiology',
#   1751    1899.66
#   1752    2220.90
#   Name: cost, dtype: float64), ('europeanjournalofhealthlaw', 334    779.72
#   Name: cost, dtype: float64), ('europeanjournalofhumangenetics',
#   1052    2400.0
#   1066    2400.0
#   Name: cost, dtype: float64), ('europeanjournalofimmunology', 940     2256.65
#   1923    1820.09
#   1924    2020.25
#   2025    2269.00
#   2026    2380.96
#   2049    1635.00
#   2069    2320.19
#   2070    2377.33
#   Name: cost, dtype: float64), ('europeanjournalofmedicalgenetics',
#   557    2281.08
#   558    2468.50
#   Name: cost, dtype: float64), ('europeanjournalofneuroscience', 1925    1500.0
#   Name: cost, dtype: float64), ('europeanjournalofpreventivecardiology',
#   1658    1920.0
#   Name: cost, dtype: float64), ('europeanjournalofpublichealth', 1214    1800.0
#   Name: cost, dtype: float64), ('europeanneuropsychopharmacology',
#   559    2325.59
#   Name: cost, dtype: float64), ('europeanradiology', 1753    2263.18
#   Name: cost, dtype: float64), ('europeanrespiratoryjournal', 851    2340.0
#   Name: cost, dtype: float64), ('evaluationinclinicalpractice', 2020    2300.38
#   Name: cost, dtype: float64), ('evidence,ethosandexperiment:theanthropologyandhistoryofmedicalresearchinafrica.',
#   171    734.0
#   172    734.0
#   Name: cost, dtype: float64), ('evodevo', 201    1564.5
#   Name: cost, dtype: float64), ('evolution', 1926    2184.22
#   1927    2374.52
#   Name: cost, dtype: float64), ('evolutionaryapplications', 2013    1524.0
#   Name: cost, dtype: float64), ('experimentalbrainresearch', 1754    1889.10
#   1755    2076.55
#   Name: cost, dtype: float64), ('experimentalcellresearch', 560    3780.0
#   Name: cost, dtype: float64), ('experimentaleyeresearch', 561    2395.43
#   Name: cost, dtype: float64), ('experimentalhematology', 562    2328.24
#   Name: cost, dtype: float64), ('experimentalneurology', 563    1771.93
#   564    2380.28
#   Name: cost, dtype: float64), ('experimentalparasitology', 565    2329.56
#   566    2441.16
#   Name: cost, dtype: float64), ('experimentalphysiology', 1928    1894.94
#   Name: cost, dtype: float64), ('expertreviewsinanti-infectivechemotherapy',
#   913    1700.0
#   Name: cost, dtype: float64), ('expertreviewsinmolecularmedicine',
#   358    3780.0
#   Name: cost, dtype: float64), ('fasebjournal', 853    1513.14
#   854    1663.37
#   855    1920.98
#   856    1953.12
#   859    1866.72
#   860    2014.37
#   864    1857.82
#   Name: cost, dtype: float64), ('febsj.', 1929    2246.21
#   1930    2247.05
#   Name: cost, dtype: float64), ('febsjournal', 1931    1500.00
#   1932    1500.00
#   2021    2430.00
#   2071    2334.91
#   Name: cost, dtype: float64), ('febsletters', 567    2228.00
#   568    2244.57
#   569    2362.82
#   570    2465.93
#   832    2143.17
#   Name: cost, dtype: float64), ('febsopenbio', 571    1254.25
#   842    1171.02
#   Name: cost, dtype: float64), ('femsmicrobiologyletters', 1933    2008.84
#   1934    2337.66
#   2072    1985.10
#   2073    2275.02
#   Name: cost, dtype: float64), ('fertilityandsterility', 572    2169.98
#   573    2373.76
#   574    2373.76
#   Name: cost, dtype: float64), ('freeradicalandbiologymedicine', 575    1755.59
#   Name: cost, dtype: float64), ('frontiers', 1034    808.85
#   Name: cost, dtype: float64), ('frontiersinauditorycognitiveneuroscience',
#   867    815.98
#   Name: cost, dtype: float64), ('frontiersinbehavioralneuroscience',
#   868    813.9
#   869    813.9
#   Name: cost, dtype: float64), ('frontiersinbrainimagingmethods',
#   870    1087.97
#   892     734.00
#   Name: cost, dtype: float64), ('frontiersincellularneuroscience',
#   871    734.00
#   872    821.98
#   Name: cost, dtype: float64), ('frontiersincognition', 873    3780.0
#   Name: cost, dtype: float64), ('frontiersincognitivescience', 874    734.0
#   Name: cost, dtype: float64), ('frontiersinconsciousnessresearch',
#   893    734.0
#   Name: cost, dtype: float64), ('frontiersindecisionneuroscience',
#   875    1392.61
#   Name: cost, dtype: float64), ('frontiersindevelopmentalpsychology',
#   876    840.19
#   Name: cost, dtype: float64), ('frontiersinelectrophysiology', 877    827.13
#   Name: cost, dtype: float64), ('frontiersinendocrinology', 878    975.81
#   Name: cost, dtype: float64), ('frontiersingenetics', 879    734.0
#   Name: cost, dtype: float64), ('frontiersinhumanneuroscience', 880    1000.87
#   881     734.00
#   882     825.37
#   883     827.13
#   898     837.74
#   Name: cost, dtype: float64), ('frontiersinimmunologicalmemory', 884    775.82
#   Name: cost, dtype: float64), ('frontiersinimmunology', 894    1014.44
#   Name: cost, dtype: float64), ('frontiersininflammation', 885    734.0
#   Name: cost, dtype: float64), ('frontiersinintegrativeneuroscience',
#   890    937.34
#   Name: cost, dtype: float64), ('frontiersininvertebratephysiology',
#   886    967.18
#   Name: cost, dtype: float64), ('frontiersinmolecularneuroscience',
#   887    1209.6
#   Name: cost, dtype: float64), ('frontiersinneuralcircuits', 895    819.45
#   Name: cost, dtype: float64), ('frontiersinneurorobotics', 896    734.0
#   Name: cost, dtype: float64), ('frontiersinperceptionscience', 891    987.91
#   Name: cost, dtype: float64), ('frontiersinschizophrenia', 888    821.98
#   Name: cost, dtype: float64), ('frontiersinsystemsneuroscience',
#   889    1644.25
#   Name: cost, dtype: float64), ('frontiersintcellbiology', 897    1017.58
#   Name: cost, dtype: float64), ('frontlinegastroenterology', 289    734.0
#   290    734.0
#   291    734.0
#   Name: cost, dtype: float64), ('fungalbiology', 576    2272.01
#   Name: cost, dtype: float64), ('fungalecology', 577    2378.19
#   Name: cost, dtype: float64), ('futuremedicinalchemistry', 903    2040.0
#   904    2270.0
#   Name: cost, dtype: float64), ('futuremicrobiology', 902    1700.0
#   Name: cost, dtype: float64), ('futureneurology', 899    2040.0
#   Name: cost, dtype: float64), ('futurevirology', 900    1850.0
#   901    2040.0
#   Name: cost, dtype: float64), ('g3:genes,genomes,genetics', 424    1230.67
#   Name: cost, dtype: float64), ('gastroenterology', 15      734.0
#   578    2228.0
#   Name: cost, dtype: float64), ('gene', 579    2406.10
#   580    2445.23
#   581    2468.74
#   Name: cost, dtype: float64), ('genes&development', 379    1501.44
#   381    1267.34
#   Name: cost, dtype: float64), ('genesbrainbehaviour', 1935    2355.52
#   2027    2408.35
#   Name: cost, dtype: float64), ('genesis:journalofgenetics', 1936    2376.4
#   Name: cost, dtype: float64), ('genetherapy', 582     2446.97
#   1035    3000.00
#   Name: cost, dtype: float64), ('geneticepidemiology', 936     2372.99
#   941     2345.75
#   2074    2286.74
#   Name: cost, dtype: float64), ('geneticepidemology', 2075    1911.3
#   Name: cost, dtype: float64), ('genetics', 425     790.93
#   426    1197.72
#   Name: cost, dtype: float64), ('geneticsinmedicine', 1036    3780.0
#   1067    3000.0
#   Name: cost, dtype: float64), ('genomebiology', 202    1788.9
#   203    1950.0
#   204    2010.0
#   Name: cost, dtype: float64), ('genomemedicine', 205    2010.0
#   267    1728.9
#   Name: cost, dtype: float64), ('genomeresearch', 382    1491.24
#   383    1548.77
#   Name: cost, dtype: float64), ('glia', 1937    1977.72
#   1938    2184.22
#   Name: cost, dtype: float64), ('glycobiology', 1169     734.0
#   1215    1700.0
#   Name: cost, dtype: float64), ('gut', 302    2040.0
#   309    2340.0
#   310    2340.0
#   Name: cost, dtype: float64), ('haematologica', 865    1567.94
#   Name: cost, dtype: float64), ('haematologica/thehaematologyjournal',
#   866    734.0
#   Name: cost, dtype: float64), ('hbmjnlhumanbrainmapping', 1939    3780.0
#   Name: cost, dtype: float64), ('health', 1678    734.0
#   Name: cost, dtype: float64), ('health&place', 583    1836.92
#   Name: cost, dtype: float64), ('health:aninterdisciplinaryjournalforthesocialstudyofhealth,illnessandmedicine',
#   1659    1920.0
#   Name: cost, dtype: float64), ('healthandplace', 584    1749.74
#   Name: cost, dtype: float64), ('healthpolicyplanning', 1132    1800.0
#   Name: cost, dtype: float64), ('healthpromotioninternational', 1216    1700.0
#   Name: cost, dtype: float64), ('healthpsychology', 49    3188.3
#   Name: cost, dtype: float64), ('heart', 311    2040.0
#   Name: cost, dtype: float64), ('heartandcirculatoryphysiology', 340    1349.18
#   Name: cost, dtype: float64), ('hepatology', 1940    1500.00
#   1941    1500.00
#   1942    1969.41
#   1943    2355.52
#   1944    2373.26
#   2014    1635.00
#   2076    1884.30
#   2077    1986.00
#   Name: cost, dtype: float64), ('heptology', 957    1852.01
#   Name: cost, dtype: float64), ('hernia', 1756    1897.21
#   Name: cost, dtype: float64), ('hippocampus', 1945    1500.00
#   1946    1500.00
#   1947    3780.00
#   2047    1409.96
#   2078    2300.12
#   Name: cost, dtype: float64), ('historyofthehumansciences', 1660    1920.0
#   1661    1920.0
#   1662    1920.0
#   1663    1920.0
#   1664    3780.0
#   Name: cost, dtype: float64), ('historyworkshopjournal', 1217    2100.0
#   Name: cost, dtype: float64), ('hpb', 2079    2311.56
#   Name: cost, dtype: float64), ('humanbrainmapping', 1948    1500.0
#   Name: cost, dtype: float64), ('humanmoleculargenetics', 1133    2040.00
#   1134    2100.00
#   1135    2100.00
#   1136    2100.00
#   1137    2100.00
#   1138    3780.00
#   1170    2040.00
#   1171    2040.00
#   1172    2100.00
#   1181    1700.00
#   1218    1978.75
#   1219    2040.00
#   1220    2040.00
#   1221    2040.00
#   1222    2040.00
#   1223    2100.00
#   1224    2100.00
#   1269    2040.00
#   1270    2040.00
#   Name: cost, dtype: float64), ('humanmoleculargeneticsonline', 1225    1700.0
#   Name: cost, dtype: float64), ('humanmolgeneticsonline', 1184    2040.0
#   Name: cost, dtype: float64), ('humanmutation', 1949    2310.95
#   2080    1986.90
#   Name: cost, dtype: float64), ('humanmutation:variation,informatics,anddisease',
#   1950    1500.0
#   Name: cost, dtype: float64), ('humanreproduction', 1226    2040.0
#   Name: cost, dtype: float64), ('humanresourcesforhealth', 240    1125.0
#   Name: cost, dtype: float64), ('humresourhealth', 229    1525.0
#   Name: cost, dtype: float64), ('ijtld', 918    2587.1
#   Name: cost, dtype: float64), ('immnunobiology', 585    2317.94
#   Name: cost, dtype: float64), ('immunity', 586    3780.0
#   587    3780.0
#   Name: cost, dtype: float64), ('immunogenetics', 1757    2211.52
#   1758    2240.86
#   Name: cost, dtype: float64), ('immunologicalreviews', 1951    1500.0
#   Name: cost, dtype: float64), ('immunology', 2050    1513.73
#   2081    2305.08
#   Name: cost, dtype: float64), ('immunologyletters', 588    2961.92
#   Name: cost, dtype: float64), ('implementsci.', 230    1345.0
#   Name: cost, dtype: float64), ('infectionandimmunity', 89     1910.82
#   90     2034.00
#   91     2249.43
#   165    1529.54
#   343    1237.76
#   Name: cost, dtype: float64), ('infectiongeneticsandevolution', 589    1770.62
#   Name: cost, dtype: float64), ('inflammationresearch', 1759    2759.24
#   Name: cost, dtype: float64), ('inflammatoryboweldiseases', 1952    1927.56
#   Name: cost, dtype: float64), ('influenzaotherrespiviruses.', 2042    1834.77
#   Name: cost, dtype: float64), ('interface', 1632    1260.0
#   Name: cost, dtype: float64), ('internationalhealth', 591    1413.88
#   Name: cost, dtype: float64), ('internationalimmunology', 1227    2040.0
#   Name: cost, dtype: float64), ('internationaljouralofepidemiology',
#   1140    2400.0
#   Name: cost, dtype: float64), ('internationaljournalforequityinhealth',
#   206    1398.0
#   Name: cost, dtype: float64), ('internationaljournalforparasitology',
#   592    1410.0
#   Name: cost, dtype: float64), ('internationaljournalofappliedearthobservationandgeoinformation',
#   593    2330.12
#   Name: cost, dtype: float64), ('internationaljournalofbehavioralnutritionandphysicalactivity',
#   207    734.0
#   Name: cost, dtype: float64), ('internationaljournalofbehaviouralnutritionandphysicalactivity',
#   208    1315.8
#   Name: cost, dtype: float64), ('internationaljournalofbiochemistry&cellbiology',
#   594    2384.53
#   Name: cost, dtype: float64), ('internationaljournalofcardiology',
#   595    1128.42
#   596    2384.22
#   597    2406.73
#   Name: cost, dtype: float64), ('internationaljournalofdevelopmentalbiology',
#   1870    1306.11
#   Name: cost, dtype: float64), ('internationaljournalofepidemiology',
#   1141    2040.0
#   1142    2400.0
#   1228    2040.0
#   1229    2400.0
#   1230    2400.0
#   Name: cost, dtype: float64), ('internationaljournalofexperimentalpathology',
#   2082    2320.03
#   Name: cost, dtype: float64), ('internationaljournaloffinancialresearch\n',
#   1676    734.0
#   Name: cost, dtype: float64), ('internationaljournalofgeriatricpsychiatry',
#   1953    2302.93
#   Name: cost, dtype: float64), ('internationaljournalofhealthgeographics',
#   209    867.38
#   Name: cost, dtype: float64), ('internationaljournaloflawincontext',
#   359    1020.0
#   Name: cost, dtype: float64), ('internationaljournalofmolecularsciences',
#   992    1384.34
#   Name: cost, dtype: float64), ('internationaljournalofobesity', 1068    3000.0
#   Name: cost, dtype: float64), ('internationaljournalofparasitology',
#   598    2386.44
#   Name: cost, dtype: float64), ('internationaljournalofrheumatology',
#   905    734.0
#   Name: cost, dtype: float64), ('internationaljournalofstroke', 1954    1500.0
#   Name: cost, dtype: float64), ('internationaljournaloftuberculosisandlungdisease',
#   919    2440.41
#   Name: cost, dtype: float64), ('internationalpsychogeriatrics', 348    2034.0
#   Name: cost, dtype: float64), ('internationalreviewsofimmunology',
#   406    2775.23
#   Name: cost, dtype: float64), ('intjepidemiol', 1139    1700.0
#   Name: cost, dtype: float64), ('intjournalforparasitology', 590    2294.0
#   Name: cost, dtype: float64), ('inyernationaljournalofepidemiology',
#   1173    2040.0
#   Name: cost, dtype: float64), ('jaidsjournalofacquiredimmunedeficiencysyndromes',
#   2119    1375.8
#   Name: cost, dtype: float64), ('jbiolchem.', 62     1487.46
#   63     1531.08
#   117    1290.23
#   118    1508.97
#   119    1521.32
#   Name: cost, dtype: float64), ('jbiolchemistry', 120    1334.16
#   Name: cost, dtype: float64), ('jcardiovascmagnreson', 1623    2350.0
#   Name: cost, dtype: float64), ('jcellsci.', 399    2400.0
#   Name: cost, dtype: float64), ('jclinmicrobiol', 344    1250.66
#   Name: cost, dtype: float64), ('jerph', 993    952.45
#   Name: cost, dtype: float64), ('jimmunol', 427     772.13
#   433    1926.45
#   Name: cost, dtype: float64), ('jinfectdis', 1266    734.0
#   Name: cost, dtype: float64), ('jmedchem', 2    734.0
#   3    734.0
#   Name: cost, dtype: float64), ('jmedchem.', 1829    1272.99
#   1830    1280.73
#   1831    1535.56
#   1832     734.00
#   Name: cost, dtype: float64), ('jmedinternetresearch', 933    1303.21
#   Name: cost, dtype: float64), ('jmolbiol', 599    2264.2
#   Name: cost, dtype: float64), ('jnlbiologicalchemistry', 161      734.0
#   338     1035.0
#   1835    3780.0
#   Name: cost, dtype: float64), ('jnloftheinternationalneuropsychologicalsociety',
#   360    2034.0
#   Name: cost, dtype: float64), ('jorgchem', 4    734.0
#   Name: cost, dtype: float64), ('jounralofclinicalmicrobiology', 111    1364.47
#   Name: cost, dtype: float64), ('journalbiologicalchemistry', 162    938.75
#   Name: cost, dtype: float64), ('journalodclinicalendocrinology',
#   1854    3602.41
#   Name: cost, dtype: float64), ('journalofabnormalpsychology', 50    2534.53
#   Name: cost, dtype: float64), ('journalofacquiredimmunedeficiencysyndromes',
#   2126    2034.75
#   Name: cost, dtype: float64), ('journalofacquiredimmunedeficiencysyndroms(jaids)',
#   2120    1836.92
#   Name: cost, dtype: float64), ('journalofaffectivedisorders', 601    2283.58
#   602    2323.49
#   603    2357.04
#   604    1530.77
#   Name: cost, dtype: float64), ('journalofaids', 2121    2009.65
#   Name: cost, dtype: float64), ('journalofallergy', 906    734.0
#   Name: cost, dtype: float64), ('journalofallergy&clinicalimmunology',
#   605    2277.79
#   606    2277.80
#   Name: cost, dtype: float64), ('journalofallergyandclinicalimmunology',
#   607    1914.82
#   608    2320.04
#   609    2382.49
#   Name: cost, dtype: float64), ('journalofalzheimerdisease', 931    780.25
#   Name: cost, dtype: float64), ('journalofanthropologicalarchaeology',
#   610    2470.01
#   Name: cost, dtype: float64), ('journalofantimicrobialchemotherapy',
#   1143    2400.0
#   1174    2040.0
#   Name: cost, dtype: float64), ('journalofappliedcrystallography',
#   926    758.53
#   Name: cost, dtype: float64), ('journalofappliedphysiology', 1833    1288.0
#   Name: cost, dtype: float64), ('journalofarchaeologicalscience',
#   611    2243.55
#   Name: cost, dtype: float64), ('journalofautismanddevelopmentaldisorders',
#   1761    2240.48
#   Name: cost, dtype: float64), ('journalofautismanddevelopmentdisorders',
#   1760    2324.76
#   Name: cost, dtype: float64), ('journalofbacteriology', 92     1343.82
#   345    2082.11
#   Name: cost, dtype: float64), ('journalofbehaviortherapyandexperimentalpsychiatry',
#   612    1442.64
#   613    2332.60
#   Name: cost, dtype: float64), ('journalofbehaviourtherapyandexperimentalpsychiatry',
#   614    2375.14
#   Name: cost, dtype: float64), ('journalofbioenergeticsandbiomembranes',
#   1801    2262.68
#   Name: cost, dtype: float64), ('journalofbioethicalinquiry', 1762    1938.26
#   Name: cost, dtype: float64), ('journalofbiolchem', 164    1055.07
#   Name: cost, dtype: float64), ('journalofbiologicalchemistry', 16      734.00
#   60     1100.00
#   61     2259.64
#   64     1019.71
#   65     1119.61
#   66     1131.01
#   67     1137.51
#   68     1152.72
#   69     1160.09
#   70     1166.85
#   71     1261.44
#   72     1276.08
#   73     1540.00
#   74     1586.36
#   75     1664.94
#   76     1743.84
#   77     2501.07
#   78      955.00
#   79      969.68
#   121    1134.50
#   122    1150.60
#   123    1225.26
#   124    1246.42
#   125    1246.76
#   126    1260.90
#   127    1276.08
#   128    1286.86
#   129    1287.75
#   130    1314.53
#   131    1343.39
#   132    1443.99
#   133    1545.10
#   134    1552.26
#   135    1556.61
#   136    1556.61
#   137    1572.24
#   138    1580.47
#   139    1600.25
#   140    1609.66
#   141    1610.31
#   142    1621.62
#   143    1707.08
#   144    1763.21
#   145    2003.13
#   146    2032.22
#   147    2311.57
#   148    2344.79
#   149    3780.00
#   150     917.50
#   151     929.31
#   152     992.01
#   163    1188.39
#   341    1804.00
#   Name: cost, dtype: float64), ('journalofbiologicalphysics', 1763    2226.16
#   Name: cost, dtype: float64), ('journalofbiomedicalgraphicsandcomputing',
#   1677    734.0
#   Name: cost, dtype: float64), ('journalofboneandmineralresearch',
#   1955    755.45
#   Name: cost, dtype: float64), ('journalofcellphysiology', 2028    2380.96
#   Name: cost, dtype: float64), ('journalofcellscience', 386     2400.0
#   400     1620.0
#   401     1620.0
#   402     2400.0
#   403     2400.0
#   404     3780.0
#   405     2000.0
#   1843    2400.0
#   Name: cost, dtype: float64), ('journalofcellularbiochemistry',
#   1956    1971.87
#   Name: cost, dtype: float64), ('journalofcerebralbloodflowandmetabolism',
#   1037    1920.0
#   1038    2040.0
#   Name: cost, dtype: float64), ('journalofchemicalinformationandmodeling',
#   10    1329.69
#   Name: cost, dtype: float64), ('journalofcheminformatics', 210    882.12
#   Name: cost, dtype: float64), ('journalofchildpsychologyandpsychiatry',
#   1957    2222.22
#   2083    1872.14
#   2084    2232.00
#   Name: cost, dtype: float64), ('journalofclinicalendocrinology',
#   1849    1970.57
#   Name: cost, dtype: float64), ('journalofclinicalendocrinologyandmetabolism',
#   376     2310.83
#   847     1995.43
#   848     2224.52
#   849     2355.52
#   1850    1909.00
#   1851    1969.56
#   1852    2320.00
#   1853    2347.87
#   Name: cost, dtype: float64), ('journalofclinicalepidemiology', 615    1955.21
#   Name: cost, dtype: float64), ('journalofclinicalmicrobiology', 98     1503.47
#   346    1289.32
#   Name: cost, dtype: float64), ('journalofclinicalpathology', 292    2340.0
#   Name: cost, dtype: float64), ('journalofclinicalvirology', 616    2486.13
#   Name: cost, dtype: float64), ('journalofcognitiveneuroscience', 995    808.85
#   Name: cost, dtype: float64), ('journalofcomparativeneurology',
#   2085    1909.73
#   Name: cost, dtype: float64), ('journalofcomputationalneuroscience',
#   1764    2241.43
#   Name: cost, dtype: float64), ('journalofconsultingandclinicalpsychology',
#   51    3037.86
#   Name: cost, dtype: float64), ('journalofculturaleconomy', 1819    2145.6
#   Name: cost, dtype: float64), ('journalofcycsticfibrosis', 617    2396.85
#   Name: cost, dtype: float64), ('journalofdepression&anxiety', 942    2321.38
#   943    2321.38
#   Name: cost, dtype: float64), ('journalofendocrinology', 247    1200.0
#   Name: cost, dtype: float64), ('journalofepidemiology&communityhealth',
#   293    1989.0
#   312    2040.0
#   Name: cost, dtype: float64), ('journalofepidemiologyandcommunityhealth',
#   323    1755.0
#   Name: cost, dtype: float64), ('journalofevaluationinclinicalpractice',
#   2086    2275.02
#   2087    2328.04
#   Name: cost, dtype: float64), ('journalofevolutionarybiology', 1958    2365.54
#   Name: cost, dtype: float64), ('journalofexperimentalnanoscience',
#   1828    2474.16
#   Name: cost, dtype: float64), ('journalofexperimentalpsychology:animalbehaviourprocess',
# ...
#   1379    1737.68
#   1380    1759.38
#   1381    1773.10
#   1382    1788.41
#   1383    1807.60
#   1384    1807.60
#   1385    1809.51
#   1386    3780.00
#   1387    3780.00
#   Name: cost, dtype: float64), ('plosmedicine', 1388    1110.04
#   1389    1814.92
#   1390    1889.00
#   1391     734.00
#   Name: cost, dtype: float64), ('plosmedicinejournal', 1392    957.04
#   Name: cost, dtype: float64), ('plosnegectedtropicaldiseases', 1393    1570.87
#   Name: cost, dtype: float64), ('plosneglectedtropicaldiseases',
#   1394    1384.96
#   1395    1395.00
#   1396    1402.74
#   1397    1403.01
#   1398    1404.41
#   1399    1427.03
#   1400    1446.13
#   1401    1456.09
#   1402    1489.67
#   1403    1507.23
#   1404    1525.00
#   1405    1561.30
#   1406    1600.25
#   1407    1661.04
#   1408    1685.39
#   1409    1750.01
#   1410    1772.81
#   1411    1773.69
#   1412    1781.11
#   1413    1843.51
#   Name: cost, dtype: float64), ('plosntd', 1281    1283.76
#   Name: cost, dtype: float64), ('plosone', 1282    1001.03
#   1283    1004.15
#   1284    1011.45
#   1285    1011.45
#   1286    1015.73
#   1287    1023.41
#   1288    1039.87
#   1289    1061.24
#   1290    1061.24
#   1291    1061.24
#   1292    1080.00
#   1293     794.93
#   1294     809.29
#   1295     819.34
#   1296     854.96
#   1297     901.50
#   1298     902.12
#   1299     903.89
#   1303    1061.93
#   1304     734.00
#   1305     734.00
#   1350     850.50
#   1414    1002.86
#   1415    1005.86
#   1416    1005.96
#   1417    1008.97
#   1418    1009.98
#   1419    1010.80
#   1420    1013.03
#   1421    1019.76
#            ...
#   1562    3780.00
#   1563    3780.00
#   1564    3780.00
#   1565    3780.00
#   1566    3780.00
#   1567     900.14
#   1568     904.34
#   1569     907.08
#   1570     908.01
#   1571     909.99
#   1572     910.20
#   1573     913.36
#   1574     915.53
#   1575     918.62
#   1576     953.48
#   1577     960.16
#   1578     961.68
#   1579     961.68
#   1580     961.68
#   1581     986.72
#   1582     996.06
#   1605     842.54
#   1606     842.54
#   1607     850.88
#   1608     871.42
#   1609     879.36
#   1610     879.36
#   1611     884.67
#   1612    3780.00
#   1613     904.34
#   Name: cost, Length: 200, dtype: float64), ('plospathogens', 1300    1343.73
#   1301    1438.45
#   1583    1254.02
#   1584    1397.00
#   1585    1404.00
#   1586    1440.00
#   1587    1600.79
#   1588    1602.17
#   1589    1644.84
#   1590    1723.16
#   1591    1735.20
#   1592    1758.16
#   1593    1766.76
#   1594    1780.00
#   1595    1782.00
#   1596    1784.65
#   1597    3780.00
#   1598    3780.00
#   1599    1440.00
#   1600    1460.30
#   1601    1476.47
#   1602    1570.87
#   1603    1600.25
#   1604    1600.25
#   Name: cost, dtype: float64), ('pmedicine-d-12-03130', 1614    3780.0
#   Name: cost, dtype: float64), ('pnas', 436      734.0
#   1002     734.0
#   1021    1069.8
#   1022     734.0
#   1308     734.0
#   1309    3780.0
#   Name: cost, dtype: float64), ('pnas(proceedingsofthenationalacademyofsciencesoftheunitedstatesofamerica',
#   1003    853.64
#   Name: cost, dtype: float64), ('pnasusa', 1310    734.0
#   Name: cost, dtype: float64), ('pntd', 1615    1488.29
#   Name: cost, dtype: float64), ('pone-d12-17947', 1616    3780.0
#   Name: cost, dtype: float64), ('population,spaceandplace', 952    1836.92
#   Name: cost, dtype: float64), ('postgraduatemedicaljournal', 326    2040.0
#   327    2040.0
#   Name: cost, dtype: float64), ('preventivemedicine', 759    1160.62
#   760    1188.83
#   761    1273.15
#   762    2321.23
#   763    2377.65
#   764    2475.13
#   Name: cost, dtype: float64), ('proceddingsofthenationalacademyofsciencesofusa',
#   1004    734.0
#   Name: cost, dtype: float64), ('proceedingsb', 1642    1260.0
#   1860    1680.0
#   Name: cost, dtype: float64), ('proceedingsofroyalsociety', 1643    1296.0
#   Name: cost, dtype: float64), ('proceedingsofthenationalacademyofsciences',
#   429     1241.10
#   430      734.00
#   431      734.00
#   1005     734.00
#   1006     734.00
#   1007     734.00
#   1008     734.00
#   1009     734.00
#   1010     734.00
#   1011     765.36
#   1012     770.75
#   1013     792.00
#   1014     793.02
#   1015     888.18
#   1017    2691.68
#   1018     751.84
#   1023     734.00
#   1024     759.30
#   1025     786.98
#   1311     734.00
#   1312     734.00
#   1315     779.69
#   Name: cost, dtype: float64), ('proceedingsofthenationalacademyofsciences(pnas)',
#   1340    831.09
#   Name: cost, dtype: float64), ('proceedingsofthenationalacademyofsciencesoftheunitedstatesofamerica',
#   1016    734.0
#   1019    734.0
#   1020    890.0
#   Name: cost, dtype: float64), ('proceedingsofthenationalacademyofsciencesoftheusa',
#   1313    809.62
#   Name: cost, dtype: float64), ('proceedingsoftheroyalsociety', 1644    1260.0
#   Name: cost, dtype: float64), ('proceedingsoftheroyalsocietyb:biologicalsciences',
#   1645    1050.0
#   1646    1400.0
#   1647    1680.0
#   1648    1680.0
#   1649    1680.0
#   1861    1260.0
#   1862    1680.0
#   1863    1680.0
#   Name: cost, dtype: float64), ('procnatlacadsciusa.', 1314    734.0
#   Name: cost, dtype: float64), ('proteinengineering,designandselection(',
#   1257    2040.0
#   Name: cost, dtype: float64), ('proteinexprpurif.', 765    1938.38
#   Name: cost, dtype: float64), ('proteinscience', 1996    1935.60
#   1997    1954.66
#   Name: cost, dtype: float64), ('protemics', 2113    1409.96
#   Name: cost, dtype: float64), ('protist', 766    2177.87
#   Name: cost, dtype: float64), ('psychologicalassessment', 55    2973.32
#   Name: cost, dtype: float64), ('psychologicalmedicine', 0       734.0
#   368    1800.0
#   411    2034.0
#   412    2034.0
#   413    2034.0
#   Name: cost, dtype: float64), ('psychologicalreview', 56    2534.53
#   Name: cost, dtype: float64), ('psychologicalscience', 1667    2297.82
#   1671    1944.14
#   Name: cost, dtype: float64), ('psychologicaltrauma:theoryresearch,practiceandpolicy',
#   57    2973.32
#   Name: cost, dtype: float64), ('psychopharmacology', 1781    1142.79
#   1782    2075.05
#   1783    2265.88
#   Name: cost, dtype: float64), ('publichealth', 222     734.00
#   767    2321.23
#   Name: cost, dtype: float64), ('publichealthethics', 1159    1800.0
#   Name: cost, dtype: float64), ('publichealthnutrition', 369    2034.0
#   414    2034.0
#   Name: cost, dtype: float64), ('publiclibraryofscience', 1617    1016.24
#   Name: cost, dtype: float64), ('publiclibraryofscienceone', 1618    1053.41
#   Name: cost, dtype: float64), ('publicservicereview', 1619    3780.0
#   Name: cost, dtype: float64), ('pulmonarypharmacology&therapeutics',
#   768    2421.77
#   Name: cost, dtype: float64), ('pyschologicalmedicine', 370    1800.0
#   Name: cost, dtype: float64), ('qjm:aninternationaljournalofmedicine',
#   1258    1700.0
#   1259    2400.0
#   Name: cost, dtype: float64), ('qualitativeresearch', 1675    3780.0
#   Name: cost, dtype: float64), ('rapidcommunicationsinmassspectrometry',
#   1998    1853.0
#   Name: cost, dtype: float64), ('reproduction(cambridge,england)',
#   250    1200.0
#   Name: cost, dtype: float64), ('reproductivemedicineandbiology',
#   1784    2242.99
#   Name: cost, dtype: float64), ('reproductivesciences', 1670    2373.77
#   Name: cost, dtype: float64), ('researchinveterinaryscience', 769    2476.85
#   Name: cost, dtype: float64), ('respiration', 968    2134.67
#   Name: cost, dtype: float64), ('respiratoryresearch', 223    1524.9
#   224    1902.0
#   234    1854.0
#   Name: cost, dtype: float64), ('rheumatology', 1160    2040.0
#   1161    2040.0
#   Name: cost, dtype: float64), ('rna', 384     910.05
#   385    1107.57
#   Name: cost, dtype: float64), ('rnabiology', 980    734.0
#   981    734.0
#   982    734.0
#   Name: cost, dtype: float64), ('rstb2012.0145', 1864    1680.0
#   Name: cost, dtype: float64), ('schizophreniabulletin', 1162    2047.5
#   1260    2040.0
#   1271    2048.0
#   Name: cost, dtype: float64), ('schizophreniaresearch', 770    2222.09
#   771    2222.09
#   Name: cost, dtype: float64), ('science-research', 1866    1224.61
#   1867     949.52
#   Name: cost, dtype: float64), ('scienceasculture', 1821    2145.6
#   Name: cost, dtype: float64), ('scientificreports', 1048    1068.0
#   1049    1068.0
#   1096    1068.0
#   Name: cost, dtype: float64), ('scientificreports-11-00861b', 1097    1068.0
#   Name: cost, dtype: float64), ('scirep', 1095    1068.0
#   Name: cost, dtype: float64), ('seizure', 772    2369.7
#   Name: cost, dtype: float64), ('seminarsinimmunopathology', 1785    1894.6
#   Name: cost, dtype: float64), ('seminarsinoncology', 773    2379.79
#   Name: cost, dtype: float64), ('sensors', 994    1290.41
#   Name: cost, dtype: float64), ('sextransminfect.', 318    1700.0
#   Name: cost, dtype: float64), ('sexuallytransmittedinfections', 300    2340.0
#   315    2040.0
#   Name: cost, dtype: float64), ('sgmopenoption', 1696    1750.0
#   Name: cost, dtype: float64), ('socialcognitiveandaffectiveneuroscience',
#   1163    1800.0
#   1164    2040.0
#   1261    2040.0
#   Name: cost, dtype: float64), ('socialhistoryofmedicine', 1179    2040.0
#   1180    2040.0
#   1262    2040.0
#   1263    2100.0
#   Name: cost, dtype: float64), ('socialpsychiatry&psychiatricepidemiology',
#   1786    1739.13
#   Name: cost, dtype: float64), ('socialpsychiatryandpsychiatricepidemiol',
#   1787    1739.13
#   1788    1739.13
#   Name: cost, dtype: float64), ('socialpsychiatryandpsychiatricepidemiology',
#   1789    1905.98
#   1790    1944.88
#   1791    1944.88
#   1792    2274.49
#   Name: cost, dtype: float64), ('socialscience&medicine', 774    2392.77
#   837    1834.77
#   Name: cost, dtype: float64), ('socialscienceandmedicine', 775    1189.77
#   776    1189.77
#   777    1836.92
#   778    2281.51
#   779    2480.56
#   Name: cost, dtype: float64), ('socialstudiesofscience', 1668    1920.0
#   Name: cost, dtype: float64), ('sociologyofhealth&illness', 1999    1514.10
#   2032    1598.18
#   Name: cost, dtype: float64), ('southasianhistoryandculture', 1826    2145.6
#   Name: cost, dtype: float64), ('speechlanguageandhearingresearch',
#   114    1969.02
#   Name: cost, dtype: float64), ('springer', 1793    1981.19
#   Name: cost, dtype: float64), ('springerscience+businessmedia',
#   1800    1117.37
#   Name: cost, dtype: float64), ('statisticsinmedicine', 2100    791.19
#   Name: cost, dtype: float64), ('stemcellreports', 375    2340.55
#   Name: cost, dtype: float64), ('stemcellresearch', 780    2215.76
#   Name: cost, dtype: float64), ('stemcells', 2000    1287.75
#   2001    1826.00
#   2048    1533.71
#   2101    1551.49
#   Name: cost, dtype: float64), ('stemcellsanddevelopment', 991    1371.54
#   Name: cost, dtype: float64), ('structure', 781    3628.83
#   782    3748.00
#   783    3780.00
#   784    3780.00
#   785    3780.00
#   786    3780.00
#   840    3780.00
#   Name: cost, dtype: float64), ('studiesinhistoryandphilosophyofsciencepartc',
#   787    2467.88
#   Name: cost, dtype: float64), ('studiesinhistoryandphilosophyofsciencepartc:studiesinhistoryandphilosophyofbiologicalandbiomedicalsciences',
#   788    2395.0
#   Name: cost, dtype: float64), ('synapse', 2102    1961.68
#   Name: cost, dtype: float64), ('tetrahedronletters', 789    1457.41
#   Name: cost, dtype: float64), ('theamericaljournalofhumangenetics',
#   790    2433.9
#   Name: cost, dtype: float64), ('theamericanjournalofhumangenetics',
#   110    2181.09
#   791    1773.74
#   792    2080.69
#   793    3714.29
#   Name: cost, dtype: float64), ('thebiochemicaljournal', 1326    1800.0
#   1327    1800.0
#   Name: cost, dtype: float64), ('thebritishjournalofpsychiatry', 1626    3000.0
#   1627    3000.0
#   Name: cost, dtype: float64), ('theembojournal', 1098    1560.0
#   1099    3120.0
#   Name: cost, dtype: float64), ('theeuropeanjournalofneuroscience',
#   2103    1982.35
#   Name: cost, dtype: float64), ('thefasebjournal', 858     824.16
#   861    1652.90
#   862    1578.93
#   863    1670.77
#   Name: cost, dtype: float64), ('thefebsjournal', 2002    1879.96
#   Name: cost, dtype: float64), ('thehistoryofthefamily', 1827    2316.79
#   Name: cost, dtype: float64), ('theinternationaljournalofbiochemistry&cellbiology',
#   794    2410.82
#   Name: cost, dtype: float64), ('thejournalofabnormalchildpsychologyandpsychiatry',
#   1794    2247.34
#   Name: cost, dtype: float64), ('thejournalofbiologicalchemistry',
#   80     1166.60
#   155    1281.15
#   156    1311.73
#   157    1324.57
#   158    1340.75
#   159    1518.46
#   160    1566.89
#   Name: cost, dtype: float64), ('thejournalofcognitiveneuroscience',
#   996    3780.0
#   Name: cost, dtype: float64), ('thejournalofimmunology', 432    2025.65
#   Name: cost, dtype: float64), ('thejournalofinfectiousdiseases',
#   1264    2040.0
#   Name: cost, dtype: float64), ('thejournalofinvestigativedermatology',
#   1100    2520.0
#   Name: cost, dtype: float64), ('thejournalofneurophysiology', 42    1276.6
#   Name: cost, dtype: float64), ('thejournalofneuroscience', 1709    2531.56
#   1714    1694.68
#   Name: cost, dtype: float64), ('thejournalofpathology', 937    2248.94
#   Name: cost, dtype: float64), ('thejournalofphysiology', 956    1870.74
#   Name: cost, dtype: float64), ('thejournalofsteroidbiochemistry&molecularbiology',
#   795    2488.17
#   Name: cost, dtype: float64), ('thejournalofvisualizedexperiments',
#   1855    1424.71
#   Name: cost, dtype: float64), ('thelancet', 796    3780.0
#   797    3780.0
#   798    3780.0
#   Name: cost, dtype: float64), ('thelancetneurology', 799    3780.0
#   800    3780.0
#   Name: cost, dtype: float64), ('theranostics', 932    734.0
#   Name: cost, dtype: float64), ('thevet.journal', 801    2480.06
#   Name: cost, dtype: float64), ('thorax', 316    2040.0
#   317    2040.0
#   Name: cost, dtype: float64), ('thoraxaninternationaljournalforrespiratorymedicine',
#   333    2340.0
#   Name: cost, dtype: float64), ('ticksandtick-bornediseases', 802    2863.73
#   Name: cost, dtype: float64), ('tissueengineering:parta', 989    1741.32
#   Name: cost, dtype: float64), ('traffic', 953     1982.81
#   2003    1500.00
#   2017    2368.66
#   2023    2307.69
#   2104    2239.22
#   2105    2377.65
#   Name: cost, dtype: float64), ('transactionsoftheroyalsocietyoftropicalmedicineandhygiene',
#   803    1524.08
#   Name: cost, dtype: float64), ('translationalpsychiatry', 1101    2880.0
#   1102    2880.0
#   Name: cost, dtype: float64), ('trendsincognitivescience', 804    2340.63
#   Name: cost, dtype: float64), ('trendsingenetics', 805    2368.11
#   806    2373.76
#   Name: cost, dtype: float64), ('trendsinmicrobiology', 807    2291.33
#   Name: cost, dtype: float64), ('trendsinmolecularmedicine', 808    2248.33
#   Name: cost, dtype: float64), ('trendsinneuroscience', 809    2402.81
#   Name: cost, dtype: float64), ('trendsinneurosciences', 810    2426.96
#   811    3780.00
#   Name: cost, dtype: float64), ('trendsinparasitology', 812    2004.74
#   813    2306.78
#   814    2461.44
#   815    3780.00
#   Name: cost, dtype: float64), ('trials', 241    1165.0
#   274    1130.4
#   275    1156.5
#   276    1350.0
#   277    3780.0
#   Name: cost, dtype: float64), ('tropicalanimalhealth&production',
#   1795    2054.78
#   Name: cost, dtype: float64), ('tropicalmedicineandinternationalhealth',
#   954     1530.77
#   955     1836.92
#   2004    1870.32
#   2005    1949.32
#   2006    1974.72
#   2018    1896.93
#   Name: cost, dtype: float64), ('tropmedinthealth', 2045    1834.77
#   Name: cost, dtype: float64), ('tuberculosis', 816    1999.94
#   817    2322.57
#   Name: cost, dtype: float64), ('urbanhistory', 371    2034.0
#   Name: cost, dtype: float64), ('urolithiasis', 1796    1112.4
#   Name: cost, dtype: float64), ('vaccine', 818    1433.34
#   819    1448.38
#   820    1477.73
#   821    2328.84
#   843    1428.68
#   Name: cost, dtype: float64), ('vascularpharmacology', 822    2352.53
#   Name: cost, dtype: float64), ('veterinarymicrobiology', 823    2451.49
#   Name: cost, dtype: float64), ('veterinaryparasitology', 824    2488.17
#   825    3780.00
#   Name: cost, dtype: float64), ('veterinaryrecord', 328    2040.0
#   Name: cost, dtype: float64), ('veterinaryresearch', 243    734.0
#   Name: cost, dtype: float64), ('virology', 826     1435.05
#   1837    2421.96
#   Name: cost, dtype: float64), ('virologyjournal', 225    1242.0
#   Name: cost, dtype: float64), ('virusresearch', 827    1947.09
#   Name: cost, dtype: float64), ('visionresearch', 828    1456.18
#   829    3780.00
#   Name: cost, dtype: float64), ('visualneuroscience', 372    2034.0
#   Name: cost, dtype: float64), ('zoonosesandpublichealth', 2106    2272.15
#   Name: cost, dtype: float64)]

# %%
df.groupby(['journal_title']).agg(
    {'cost': ['mean', 'median', 'std']})
# Out:
#                                                            cost            \
#                                                            mean    median
# journal_title
# academyofnutritionanddietetics                      2379.540000  2379.540
# acschemicalbiology                                  1418.186000  1294.590
# acschemicalneuroscience                             1186.800000  1186.800
# acsnano                                              734.000000   734.000
# actacrystallographica,sectiond                       757.180000   757.180
# actacrystallographicasectiond,biologicalcrystal...   771.420000   771.420
# actacrystallographicasectiond:biologicalcrystal...   773.740000   773.740
# actacrystallographicasectionf:structuralbiology...   796.635000   796.635
# actacrystallographyd                                 774.190000   774.190
# actad                                                750.160000   750.160
# actadermatovenereologica                             734.000000   734.000
# actadiabetologica                                   2336.280000  2336.280
# actaf                                                754.900000   754.900
# actaneuropathol                                     1901.040000  1901.040
# actaneuropathologica                                2161.063333  2250.970
# actaopthalmologica                                  2270.160000  2270.160
# actaphysiol                                         1991.500000  1991.500
# addiction                                           2136.225000  2136.225
# advancesinexperimentalmedicineandbiology            1928.457500  1928.460
# age                                                 2170.140000  2170.140
# ageandageing                                        2040.000000  2040.000
# ageing&society                                      1695.000000  1695.000
# agingcell                                           1970.570000  1970.570
# aids                                                2059.306667  1968.630
# aidsbehav                                           1834.770000  1834.770
# aidscare                                            2294.225000  2316.010
# aidsjournal                                         2015.720000  2015.720
# aidsresearchandtherapy                              1240.000000  1240.000
# aidsuk                                              1836.920000  1836.920
# alcoholandalcoholism                                2040.000000  2040.000
# ...                                                         ...       ...
# tissueengineering:parta                             1741.320000  1741.320
# traffic                                             2129.338333  2273.455
# transactionsoftheroyalsocietyoftropicalmedicine...  1524.080000  1524.080
# translationalpsychiatry                             2880.000000  2880.000
# trendsincognitivescience                            2340.630000  2340.630
# trendsingenetics                                    2370.935000  2370.935
# trendsinmicrobiology                                2291.330000  2291.330
# trendsinmolecularmedicine                           2248.330000  2248.330
# trendsinneuroscience                                2402.810000  2402.810
# trendsinneurosciences                               3103.480000  3103.480
# trendsinparasitology                                2638.240000  2384.110
# trials                                              1716.380000  1165.000
# tropicalanimalhealth&production                     2054.780000  2054.780
# tropicalmedicineandinternationalhealth              1843.163333  1883.625
# tropmedinthealth                                    1834.770000  1834.770
# tuberculosis                                        2161.255000  2161.255
# urbanhistory                                        2034.000000  2034.000
# urolithiasis                                        1112.400000  1112.400
# vaccine                                             1623.394000  1448.380
# vascularpharmacology                                2352.530000  2352.530
# veterinarymicrobiology                              2451.490000  2451.490
# veterinaryparasitology                              3134.085000  3134.085
# veterinaryrecord                                    2040.000000  2040.000
# veterinaryresearch                                   734.000000   734.000
# virology                                            1928.505000  1928.505
# virologyjournal                                     1242.000000  1242.000
# virusresearch                                       1947.090000  1947.090
# visionresearch                                      2618.090000  2618.090
# visualneuroscience                                  2034.000000  2034.000
# zoonosesandpublichealth                             2272.150000  2272.150
#
#
#                                                             std
# journal_title
# academyofnutritionanddietetics                              NaN
# acschemicalbiology                                   507.309560
# acschemicalneuroscience                                     NaN
# acsnano                                                0.000000
# actacrystallographica,sectiond                              NaN
# actacrystallographicasectiond,biologicalcrystal...          NaN
# actacrystallographicasectiond:biologicalcrystal...          NaN
# actacrystallographicasectionf:structuralbiology...    15.605847
# actacrystallographyd                                        NaN
# actad                                                       NaN
# actadermatovenereologica                                    NaN
# actadiabetologica                                           NaN
# actaf                                                       NaN
# actaneuropathol                                             NaN
# actaneuropathologica                                 244.811798
# actaopthalmologica                                          NaN
# actaphysiol                                                 NaN
# addiction                                            306.481292
# advancesinexperimentalmedicineandbiology               0.005000
# age                                                  237.785868
# ageandageing                                                NaN
# ageing&society                                              NaN
# agingcell                                                   NaN
# aids                                                 281.067979
# aidsbehav                                                   NaN
# aidscare                                             126.415851
# aidsjournal                                                 NaN
# aidsresearchandtherapy                                      NaN
# aidsuk                                                 0.000000
# alcoholandalcoholism                                        NaN
# ...                                                         ...
# tissueengineering:parta                                     NaN
# traffic                                              340.691688
# transactionsoftheroyalsocietyoftropicalmedicine...          NaN
# translationalpsychiatry                                0.000000
# trendsincognitivescience                                    NaN
# trendsingenetics                                       3.995153
# trendsinmicrobiology                                        NaN
# trendsinmolecularmedicine                                   NaN
# trendsinneuroscience                                        NaN
# trendsinneurosciences                                956.743759
# trendsinparasitology                                 784.445052
# trials                                              1156.894538
# tropicalanimalhealth&production                             NaN
# tropicalmedicineandinternationalhealth               161.141743
# tropmedinthealth                                            NaN
# tuberculosis                                         228.133861
# urbanhistory                                                NaN
# urolithiasis                                                NaN
# vaccine                                              394.821486
# vascularpharmacology                                        NaN
# veterinarymicrobiology                                      NaN
# veterinaryparasitology                               913.461753
# veterinaryrecord                                            NaN
# veterinaryresearch                                          NaN
# virology                                             697.850753
# virologyjournal                                             NaN
# virusresearch                                               NaN
# visionresearch                                      1643.188880
# visualneuroscience                                          NaN
# zoonosesandpublichealth                                     NaN
#
# [895 rows x 3 columns]
